# %% [markdown]
# # Short-Term Memory

# %%
import dotenv
from agents import Agent, Runner, SQLiteSession, trace

dotenv.load_dotenv()
# Out:
# True

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant comparing how healthy different foods are.
    If you answer, give a list of how healthy the foods are with a score from 1 to 10. Order by: healtiest food comes first.

    Example:
    Q: Compare X and Y
    A: X is healtier as Y.
    1) X: 8/10 - Very healthy but high in fructose
    2) Y: 3/10 - High in sugar and fat
    """,
)

# %% [markdown]
# ## No Memory

# %%
result = await Runner.run(nutrition_agent, "Which is healthier, bananas or lollipop?")
print(result.final_output)
# Out:
# 1) Bananas: 7/10 - Nutritious: fiber, potassium, vitamins; moderate natural sugars.
# 2) Lollipop: 2/10 - High refined sugar, no nutrients.

# %%
result = await Runner.run(nutrition_agent, "Add apples to the comparison")
print(result.final_output)
# Out:
# Please specify which other foods to compare apples against (or provide the current list you’re using). I’ll add apples and output a ranked list with scores 1–10. If you’d like a quick sample, I can compare apples with bananas, carrots, and cookies.

# %% [markdown]
# ## Short Term Memory

# %%
session = SQLiteSession("conversation_history")

# %%
result = await Runner.run(
    nutrition_agent, "Which is healthier, bananas or lollipop?", session=session
)
print(result.final_output)
# Out:
# Banana is healthier than Lollipop.
#
# 1) Banana: 9/10 - Rich in potassium, fiber, vitamins; natural sugars but overall nutrient-dense.
# 2) Lollipop: 2/10 - Mostly sugar with minimal nutrients; empty calories.

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(
        nutrition_agent, "Add apples to the comparison", session=session
    )

print(result.final_output)
# Out:
# Banana, Apple, Lollipop in order.
#
# 1) Banana: 9/10 - Rich in potassium, fiber, vitamins; natural sugars but nutrient-dense.
# 2) Apple: 8/10 - Good fiber and vitamin C, antioxidants; moderate sugar; low calories.
# 3) Lollipop: 2/10 - Mostly sugar with minimal nutrients; empty calories.
